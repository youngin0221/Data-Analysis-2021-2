# %%
import pandas as pd
import folium

# %%
df = pd.read_csv('지하철_전처리.csv', encoding= 'cp949')
df
# Out:
#           호선      역명     구            동     역코드         위도          경도  \
# 0       01호선      서울  세종대로        봉래동2가   150.0  37.554648  126.972559
# 1       01호선      시청  세종대로           정동   151.0  37.564718  126.977108
# 2       01호선      종각   종로구  종로1.2.3.5가동   152.0  37.570161  126.982923
# 3       01호선    종로3가   종로구  종로1.2.3.4가동   153.0  37.571607  126.991806
# 4       01호선    종로5가   종로구      종로5.6가동   154.0  37.570926  127.001849
# ..       ...     ...   ...          ...     ...        ...         ...
# 385  우이신설경전철  북한산보국문   성북구          정릉동  4709.0  37.612343  127.008009
# 386  우이신설경전철      정릉   성북구          정릉동  4710.0  37.602798  127.013490
# 387  우이신설경전철  성신여대입구   성북구          동선동  4711.0  37.592624  127.016403
# 388  우이신설경전철      보문   성북구          보문동  4712.0  37.585286  127.019381
# 389  우이신설경전철     신설동  동대문구          신설동  4713.0  37.575297  127.025087
#
#                                           주소
# 0        서울특별시 세종대로 지하 2 (남대문로 5가) (1호선 서울역)
# ...

# %%
import json
geo_str = json.load(open('skorea_municipalities_geo_simple.json',
                         encoding='utf8'))

# %%
df1 = df[df['호선']=='01호선']
df2 = df[df['호선']=='02호선']
df3 = df[df['호선']=='03호선']
df4 = df[df['호선']=='04호선']
df5 = df[df['호선']=='05호선']
df6 = df[df['호선']=='06호선']
df7 = df[df['호선']=='07호선']
df8 = df[df['호선']=='08호선']
df9 = df[df['호선']=='09호선']
dfk1 = df[df['호선']=='경의선']
dfk2 = df[df['호선']=='경춘선']
dfk3 = df[df['호선']=='김포도시철도']
dfg = df[df['호선']=='공항철도']
dfb = df[df['호선']=='분당선']
dfs = df[df['호선']=='신분당선']
dfu = df[df['호선']=='우이신설경전철']

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df1.index:
    folium.Circle(
        location=[df1['위도'][i], df1['경도'][i]],
        color='#0052A4', tooltip=f"{df1.역명[i]}").add_to(map)

map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df2.index:
    folium.Circle(
        location=[df2['위도'][i], df2['경도'][i]],
        color='#009D3E', tooltip=f"{df2.역명[i]}").add_to(map)

map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df3.index:
    folium.Circle(
        location=[df3['위도'][i], df3['경도'][i]],
        color='#EF7C1C', tooltip=f"{df3.역명[i]}").add_to(map)

map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df4.index:
    folium.Circle(
        location=[df4['위도'][i], df4['경도'][i]],
        color='#00A5DE', tooltip=f"{df4.역명[i]}").add_to(map)

map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df5.index:
    folium.Circle(
        location=[df5['위도'][i], df5['경도'][i]],
        color='#996CAC', tooltip=f"{df5.역명[i]}").add_to(map)



for i in df6.index:
    folium.Circle(
        location=[df6['위도'][i], df6['경도'][i]],
        color='#CD7C2F',tooltip=f"{df6.역명[i]}").add_to(map)
for i in df7.index:
    folium.Circle(
        location=[df7['위도'][i], df7['경도'][i]],
        color='#747F00', tooltip=f"{df7.역명[i]}").add_to(map)
for i in df8.index:
    folium.Circle(
        location=[df8['위도'][i], df8['경도'][i]],
        color='#EA545D', tooltip=f"{df8.역명[i]}").add_to(map)
for i in df9.index:
    folium.Circle(
        location=[df9['위도'][i], df9['경도'][i]],
        color='#BB8336', tooltip=f"{df9.역명[i]}").add_to(map)
for i in dfk1.index:
    folium.Circle(
        location=[dfk1['위도'][i], dfk1['경도'][i]],
        color='#77C4A3', tooltip=f"{dfk1.역명[i]}").add_to(map)
for i in dfk2.index:
    folium.Circle(
        location=[dfk2['위도'][i], dfk2['경도'][i]],
        color='#0C8E72', tooltip=f"{dfk2.역명[i]}").add_to(map)
for i in dfk3.index:
    folium.Circle(
        location=[dfk3['위도'][i], dfk3['경도'][i]],
        color='#A17800', tooltip=f"{dfk3.역명[i]}").add_to(map)
for i in dfg.index:
    folium.Circle(
        location=[dfg['위도'][i], dfg['경도'][i]],
        color='#0065B3', tooltip=f"{dfg.역명[i]}").add_to(map)
for i in dfb.index:
    folium.Circle(
        location=[dfb['위도'][i], dfb['경도'][i]],
        color='#F5A200',tooltip=f"{dfb.역명[i]}").add_to(map)
for i in dfs.index:
    folium.Circle(
        location=[dfs['위도'][i], dfs['경도'][i]],
        color='#D4003B', tooltip=f"{dfs.역명[i]}").add_to(map)
for i in dfu.index:
    folium.Circle(
        location=[dfu['위도'][i], dfu['경도'][i]],
        color='#B7C452', tooltip=f"{dfu.역명[i]}").add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map.save('subway.html')

# %% [markdown]
# ## 1호선

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df1.index:
    folium.CircleMarker([df1['위도'][i], df1['경도'][i]], radius=10, color='#', fill_color='#0052A4', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df1['위도'][i], df1['경도'][i]],
        color='#0052A4', tooltip=f"{df1.역명[i]}").add_to(map)
    folium.CircleMarker()
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 2호선

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df2.index:
    folium.CircleMarker(
        [df2['위도'][i], df2['경도'][i]], 
        radius=10, color='#', fill_color='#009D3E', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df2['위도'][i], df2['경도'][i]],
        radius = 5, color='#009D3E', tooltip=f"{df2.역명[i]}").add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 3호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df3.index:
    folium.CircleMarker(
        [df3['위도'][i], df3['경도'][i]], 
        radius=10, color='#', fill_color='#EF7C1C', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df3['위도'][i], df3['경도'][i]],
        radius = 5, color='#EF7C1C', tooltip=f"{df3.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 4호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df4.index:
    folium.CircleMarker(
        [df4['위도'][i], df4['경도'][i]], 
        radius=10, color='#', fill_color='#00A5DE', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df4['위도'][i], df4['경도'][i]],
        radius = 5, color='#00A5DE', tooltip=f"{df4.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 5호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df5.index:
    folium.CircleMarker(
        [df5['위도'][i], df5['경도'][i]], 
        radius=10, color='#', fill_color='#996CAC', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df5['위도'][i], df5['경도'][i]],
        radius = 5, color='#996CAC', tooltip=f"{df5.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 6호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df6.index:
    folium.CircleMarker(
        [df6['위도'][i], df6['경도'][i]], 
        radius=10, color='#', fill_color='#CD7C2F', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df6['위도'][i], df6['경도'][i]],
        radius = 5, color='#CD7C2F',tooltip=f"{df6.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 7호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df7.index:
    folium.CircleMarker(
        [df7['위도'][i], df7['경도'][i]], 
        radius=10, color='#', fill_color='#747F00', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df7['위도'][i], df7['경도'][i]],
        radius = 5, color='#747F00', tooltip=f"{df7.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 8호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df8.index:
    folium.CircleMarker(
        [df8['위도'][i], df8['경도'][i]], 
        radius=10, color='#', fill_color='#EA545D', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df8['위도'][i], df8['경도'][i]],
        radius = 5, color='#EA545D', tooltip=f"{df8.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 9호선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in df9.index:
    folium.CircleMarker(
        [df9['위도'][i], df9['경도'][i]], 
        radius=10, color='#', fill_color='#BB8336', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df9['위도'][i], df9['경도'][i]],
        radius = 5, color='#BB8336', tooltip=f"{df9.역명[i]}").add_to(map)
map
# Out:
# C:\Users\CPB06GameN\miniconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ...

# %% [markdown]
# ## 경의선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfk1.index:
    folium.CircleMarker(
        [dfk1['위도'][i], dfk1['경도'][i]], 
        radius=10, color='#', fill_color='#77C4A3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk1['위도'][i], dfk1['경도'][i]],
        radius = 5, color='#77C4A3', tooltip=f"{dfk1.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 경춘선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfk2.index:
    folium.CircleMarker(
        [dfk2['위도'][i], dfk2['경도'][i]], 
        radius=10, color='#', fill_color='#0C8E72', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk2['위도'][i], dfk2['경도'][i]],
        radius = 5, color='#0C8E72', tooltip=f"{dfk2.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 김포도시철도

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfk3.index:
    folium.CircleMarker(
        [dfk3['위도'][i], dfk3['경도'][i]], 
        radius=10, color='#', fill_color='#A17800', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk3['위도'][i], dfk3['경도'][i]],
        radius = 5, color='#A17800', tooltip=f"{dfk3.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 공항철도

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfg.index:
    folium.CircleMarker(
        [dfg['위도'][i], dfg['경도'][i]], 
        radius=10, color='#', fill_color='#0065B3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfg['위도'][i], dfg['경도'][i]],
        radius = 5, color='#0065B3', tooltip=f"{dfg.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 분당선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfb.index:
    folium.CircleMarker(
        [dfb['위도'][i], dfb['경도'][i]], 
        radius=10, color='#', fill_color='#F5A200', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfb['위도'][i], dfb['경도'][i]],
        radius = 5, color='#F5A200',tooltip=f"{dfb.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 신분당선

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfs.index:
    folium.CircleMarker(
        [dfs['위도'][i], dfs['경도'][i]], 
        radius=10, color='#', fill_color='#D4003B', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfs['위도'][i], dfs['경도'][i]],
        radius = 5, color='#D4003B', tooltip=f"{dfs.역명[i]}").add_to(map)
map

# %% [markdown]
# ## 우이신설경전철

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')
for i in dfu.index:
    folium.CircleMarker(
        [dfu['위도'][i], dfu['경도'][i]], 
        radius=10, color='#', fill_color='#B7C452', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfu['위도'][i], dfu['경도'][i]],
        radius = 5, color='#B7C452', tooltip=f"{dfu.역명[i]}").add_to(map)
map

# %%
map = folium.Map(location=[df3['위도'].mean(), df3['경도'].mean()], tiles='cartodb positron', zoom_start=11)

map.choropleth(
    geo_data = geo_str,
    fill_color = 'snow')

for i in df1.index:
    folium.CircleMarker(
        [df1['위도'][i], df1['경도'][i]], 
        radius=10, color='#', fill_color='#0052A4', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df1['위도'][i], df1['경도'][i]],
        radius = 5, color='#0052A4', tooltip=f"{df1.역명[i]}").add_to(map)
for i in df2.index:
    folium.CircleMarker(
        [df2['위도'][i], df2['경도'][i]], 
        radius=10, color='#', fill_color='#009D3E', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df2['위도'][i], df2['경도'][i]],
        radius = 5, color='#009D3E', tooltip=f"{df2.역명[i]}").add_to(map)
for i in df3.index:
    folium.CircleMarker(
        [df3['위도'][i], df3['경도'][i]], 
        radius=10, color='#', fill_color='#EF7C1C', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df3['위도'][i], df3['경도'][i]],
        radius = 5, color='#EF7C1C', tooltip=f"{df3.역명[i]}").add_to(map)
for i in df4.index:
    folium.CircleMarker(
        [df4['위도'][i], df4['경도'][i]], 
        radius=10, color='#', fill_color='#00A5DE', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df4['위도'][i], df4['경도'][i]],
        radius = 5, color='#00A5DE', tooltip=f"{df4.역명[i]}").add_to(map)
for i in df5.index:
    folium.CircleMarker(
        [df5['위도'][i], df5['경도'][i]], 
        radius=10, color='#', fill_color='#996CAC', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df5['위도'][i], df5['경도'][i]],
        radius = 5, color='#996CAC', tooltip=f"{df5.역명[i]}").add_to(map)
for i in df6.index:
    folium.CircleMarker(
        [df6['위도'][i], df6['경도'][i]], 
        radius=10, color='#', fill_color='#CD7C2F', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df6['위도'][i], df6['경도'][i]],
        radius = 5, color='#CD7C2F',tooltip=f"{df6.역명[i]}").add_to(map)
for i in df7.index:
    folium.CircleMarker(
        [df7['위도'][i], df7['경도'][i]], 
        radius=10, color='#', fill_color='#747F00', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df7['위도'][i], df7['경도'][i]],
        radius = 5, color='#747F00', tooltip=f"{df7.역명[i]}").add_to(map)
for i in df8.index:
    folium.CircleMarker(
        [df8['위도'][i], df8['경도'][i]], 
        radius=10, color='#', fill_color='#EA545D', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df8['위도'][i], df8['경도'][i]],
        radius = 5, color='#EA545D', tooltip=f"{df8.역명[i]}").add_to(map)
for i in df9.index:
    folium.CircleMarker(
        [df9['위도'][i], df9['경도'][i]], 
        radius=10, color='#', fill_color='#BB8336', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[df9['위도'][i], df9['경도'][i]],
        radius = 5, color='#BB8336', tooltip=f"{df9.역명[i]}").add_to(map)
for i in dfk1.index:
    folium.CircleMarker(
        [dfk1['위도'][i], dfk1['경도'][i]], 
        radius=10, color='#', fill_color='#77C4A3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk1['위도'][i], dfk1['경도'][i]],
        radius = 5, color='#77C4A3', tooltip=f"{dfk1.역명[i]}").add_to(map)
for i in dfk2.index:
    folium.CircleMarker(
        [dfk2['위도'][i], dfk2['경도'][i]], 
        radius=10, color='#', fill_color='#0C8E72', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk2['위도'][i], dfk2['경도'][i]],
        radius = 5, color='#0C8E72', tooltip=f"{dfk2.역명[i]}").add_to(map)
for i in dfk3.index:
    folium.CircleMarker(
        [dfk3['위도'][i], dfk3['경도'][i]], 
        radius=10, color='#', fill_color='#A17800', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfk3['위도'][i], dfk3['경도'][i]],
        radius = 5, color='#A17800', tooltip=f"{dfk3.역명[i]}").add_to(map)
for i in dfg.index:
    folium.CircleMarker(
        [dfg['위도'][i], dfg['경도'][i]], 
        radius=10, color='#', fill_color='#0065B3', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfg['위도'][i], dfg['경도'][i]],
        radius = 5, color='#0065B3', tooltip=f"{dfg.역명[i]}").add_to(map)
for i in dfb.index:
    folium.CircleMarker(
        [dfb['위도'][i], dfb['경도'][i]], 
        radius=10, color='#', fill_color='#F5A200', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfb['위도'][i], dfb['경도'][i]],
        radius = 5, color='#F5A200',tooltip=f"{dfb.역명[i]}").add_to(map)
for i in dfs.index:
    folium.CircleMarker(
        [dfs['위도'][i], dfs['경도'][i]], 
        radius=10, color='#', fill_color='#D4003B', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfs['위도'][i], dfs['경도'][i]],
        radius = 5, color='#D4003B', tooltip=f"{dfs.역명[i]}").add_to(map)
for i in dfu.index:
    folium.CircleMarker(
        [dfu['위도'][i], dfu['경도'][i]], 
        radius=10, color='#', fill_color='#B7C452', fill_opacity=0.1).add_to(map)
    folium.Circle(
        location=[dfu['위도'][i], dfu['경도'][i]],
        radius = 5, color='#B7C452', tooltip=f"{dfu.역명[i]}").add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
map.save('subway.html')
